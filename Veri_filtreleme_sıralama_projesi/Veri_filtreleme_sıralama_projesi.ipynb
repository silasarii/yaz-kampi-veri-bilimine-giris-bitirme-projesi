# %%
# Veri Filtreleme & Sıralama Notebook
# Bu notebook .ipynb olarak çalıştırılmak üzere hazırlandı.
# İçinde hem kodlar hem de veriye dair analiz (yorum) hücreleri bulunuyor.

# %%
import pandas as pd

# %%
data = pd.read_csv('country.csv')
data.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
# Veri Seti Açıklaması:
# - Country: Ülkenin adı
# - Region: Ülkenin bulunduğu bölge (ör. ASIA, EASTERN EUROPE, NORTHERN AFRICA vb.)
# - Population: Ülkenin toplam nüfusu
# - Area (sq. mi.): Ülkenin yüzölçümü (mil kare olarak)
# - Pop. Density (per sq. mi.): Nüfus yoğunluğu (mil kare başına düşen kişi sayısı)
# - Coastline (coast/area ratio): Sahil uzunluğunun, ülkenin toplam alanına oranı
# - Net migration: Net göç oranı (ülkeye giren veya çıkan kişi sayısına göre)
# - Infant mortality (per 1000 births): Bebek ölüm oranı (1000 doğum başına)
# - GDP ($ per capita): Kişi başına düşen Gayri Safi Yurtiçi Hasıla (GSYİH)
# - Literacy (%): Okur-yazarlık oranı
# - Phones (per 1000): Her 1000 kişi başına düşen telefon sayısı
# - Arable (%): Tarıma elverişli arazi yüzdesi
# - Crops (%): Ekilebilir ürünlerin yüzdesi
# - Other (%): Diğer arazi kullanımı yüzdesi
# - Climate: Ülkenin iklim kategorisi (numerik değer)
# - Birthrate: Doğum oranı
# - Deathrate: Ölüm oranı
# - Agriculture: Tarım sektörünün ekonomideki payı
# - Industry: Sanayi sektörünün ekonomideki payı
# - Service: Hizmet sektörünün ekonomideki payı

# %% [markdown]
# #### Nüfusa Göre Azalan Sıralama

# %%
data_sorted_population = data.sort_values(by='Population', ascending=False)
data_sorted_population.head(10)
# Out:
#             Country                               Region  Population  \
# 42           China         ASIA (EX. NEAR EAST)           1313973713
# 94           India         ASIA (EX. NEAR EAST)           1095351995
# 214  United States   NORTHERN AMERICA                      298444215
# 95       Indonesia         ASIA (EX. NEAR EAST)            245452739
# 27          Brazil               LATIN AMER. & CARIB       188078227
# 156       Pakistan         ASIA (EX. NEAR EAST)            165803560
# 16      Bangladesh         ASIA (EX. NEAR EAST)            147365352
# 169         Russia                  C.W. OF IND. STATES    142893540
# 152        Nigeria   SUB-SAHARAN AFRICA                    131859731
# 103          Japan         ASIA (EX. NEAR EAST)            127463611
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 42          9596960                      136,9                         0,15
# ...

# %% [markdown]
# ##### Gözlem:
# - Nüfus açısından en kalabalık ülkeler Çin, Hindistan ve ABD olarak sıralanıyor.
# - Asya ülkeleri (Çin, Hindistan, Endonezya, Pakistan, Bangladeş, Japonya) listeye ağırlıklı olarak hakim.
# - Nüfus yoğunluğu bakımından Bangladeş (1023,4 kişi/sq.mi.) ve Hindistan (333,2 kişi/sq.mi.) oldukça yüksek yoğunluğa sahip, buna karşılık Rusya (8,4 kişi/sq.mi.) ve ABD (31 kişi/sq.mi.) düşük yoğunlukta.
# - GSYİH (GDP per capita) açısından ABD ve Japonya öne çıkarken, Bangladeş, Pakistan gibi ülkeler oldukça düşük değerlerde.
# - Literacy (%) değerleri yüksek olan ülkeler Japonya, Rusya, ABD gibi ülkeler.
# - Bu sıralama yalnızca nüfus büyüklüğüne odaklanıyor, diğer ekonomik veya sosyal göstergeleri hesaba katmıyor.
#
# ##### Yorum:
# - Nüfus büyüklüğü, ülke ekonomisi, altyapı ve kaynak yönetimi açısından kritik bir faktör.
# - Yüksek nüfuslu ülkelerde altyapı ve sosyal hizmetler üzerindeki baskı artabilir; düşük nüfus yoğunluğu ise kaynakların daha geniş alana yayılmasını sağlar.
# - Analiz, yalnızca nüfusa göre sıralandığından, GDP, Literacy veya Population Density gibi diğer göstergelerle birlikte incelendiğinde daha anlamlı çıkarımlar yapılabilir.

# %% [markdown]
# #### GDP per capita’ye göre artan sıralama

# %%
data_sorted_gdp = data.sort_values(by='GDP ($ per capita)', ascending=True)
data_sorted_gdp.head(10)
# Out:
#                    Country                               Region  Population  \
# 58             East Timor         ASIA (EX. NEAR EAST)              1062777
# 188               Somalia   SUB-SAHARAN AFRICA                      8863338
# 183          Sierra Leone   SUB-SAHARAN AFRICA                      6005250
# 33                Burundi   SUB-SAHARAN AFRICA                      8090068
# 200              Tanzania   SUB-SAHARAN AFRICA                     37445392
# 74             Gaza Strip   NEAR EAST                               1428757
# 125                Malawi   SUB-SAHARAN AFRICA                     13013926
# 0             Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 46   Congo, Repub. of the   SUB-SAHARAN AFRICA                      3702314
# 63                Eritrea   SUB-SAHARAN AFRICA                      4786994
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %% [markdown]
# ##### Gözlem:
# - GDP ($ per capita) açısından en düşük değerler 500-700 USD civarında. Bu ülkeler genellikle Afrika (Somalia, Sierra Leone, Malawi, Eritrea) ve Asya (East Timor, Afghanistan) bölgelerinde yer alıyor.
# - En düşük GSYİH’lı ülkelerde literacy (%), infant mortality ve population yoğunluğu farklılık gösteriyor. Örneğin, literacy oranı 31,4 (Sierra Leone) ile 62,7 (Malawi) arasında değişiyor.
# - Phones per 1000 ve diğer altyapı göstergeleri düşük GSYİH’lı ülkelerde oldukça sınırlı. Örneğin East Timor’da telefon sayısı veri olarak eksik, Gaza Strip’te 244,3 ile yüksek bir istisna.
# - Nüfus yoğunluğu bazı düşük GSYİH’lı ülkelerde yüksek (Burundi: 290,7 kişi/sq.mi, Gaza Strip: 3968,8 kişi/sq.mi), bazı ülkelerde düşük (Somalia: 13,9 kişi/sq.mi).
#
# ##### Yorum:
# - Kişi başına düşen GSYİH, ülkelerin ekonomik gelişmişlik düzeyini yansıtır ve altyapı, eğitim, sağlık gibi sosyal göstergelerle yakından ilişkilidir.
# - Bu sıralama, ekonomik açıdan en zayıf ülkeleri hızlıca belirlemek için kullanılabilir.
# - Bazı ülkelerde nüfus yoğunluğu ve altyapı göstergeleri yüksekken GSYİH düşük; bu, kaynakların etkin kullanımında ve gelir dağılımında problemler olabileceğine işaret ediyor.
# - Analiz, düşük GSYİH’lı ülkelerde sosyal ve ekonomik politikaların iyileştirilmesi gerektiğini ortaya koyuyor.

# %% [markdown]
# #### Population > 10 milyon filtreleme

# %%
population_over_10m = data[data['Population'] > 10_000_000]
population_over_10m
# Out:
#           Country                               Region  Population  \
# 0    Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 2        Algeria   NORTHERN AFRICA                        32930091
# 5         Angola   SUB-SAHARAN AFRICA                     12127071
# 8      Argentina               LATIN AMER. & CARIB        39921833
# 11     Australia   OCEANIA                                20264082
# ..            ...                                  ...         ...
# 218    Venezuela               LATIN AMER. & CARIB        25730435
# 219      Vietnam         ASIA (EX. NEAR EAST)             84402966
# 224        Yemen   NEAR EAST                              21456188
# 225       Zambia   SUB-SAHARAN AFRICA                     11502010
# 226     Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0            647500                       48,0                         0,00
# ...

# %% [markdown]
# ##### Gözlem:
# * Filtreleme sonucunda, dünya genelinde 10 milyonun üzerinde nüfusa sahip ülkeler seçildi.
# * Bu ülkeler Asya, Afrika, Latin Amerika ve Okyanusya gibi farklı bölgelerden geliyor.
# * Nüfus bakımından en büyük ülkeler Çin, Hindistan, ABD ve Endonezya gibi ülkeler.
# * Bu ülkelerde nüfus yoğunluğu, yüzölçümü ve diğer demografik göstergeler arasında büyük farklılıklar gözlemleniyor. Örneğin Çin ve Hindistan, yüzölçümü büyük olmasına rağmen yüksek nüfus yoğunluğuna sahipken, Avustralya çok düşük nüfus yoğunluğuna sahip.
#
# ##### Yorum:
# * Nüfusu 10 milyonun üzerinde olan ülkeler, ekonomik, sosyal ve altyapısal planlama açısından daha büyük ölçekli politikalar gerektiriyor.
# * Bu filtreleme, yüksek nüfuslu ülkelerin analizlerde ayrı bir gruplandırma veya karşılaştırma yapılabilmesini sağlıyor.
# * Aynı zamanda, yüksek nüfuslu ülkelerde diğer göstergeler (GSYİH, okur-yazarlık oranı, sağlık göstergeleri) daha geniş varyans gösteriyor, bu da veri analizinde dikkat edilmesi gereken bir noktadır.

# %% [markdown]
# #### En yüksek okur-yazarlık oranına sahip ilk 5 ülke

# %%
top_5_literacy = data.sort_values(by='Literacy (%)', ascending=False).head(5)
top_5_literacy
# Out:
#              Country                               Region  Population  \
# 53   Czech Republic   EASTERN EUROPE                         10235455
# 93          Iceland   WESTERN EUROPE                           299388
# 163          Poland   EASTERN EUROPE                         38536869
# 114          Latvia   BALTICS                                 2274735
# 64          Estonia   BALTICS                                 1324333
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 53            78866                      129,8                         0,00
# 93           103000                        2,9                         4,83
# 163          312685                      123,3                         0,16
# 114           64589                       35,2                         0,82
# 64            45226                       29,3                         8,39
#
#     Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %% [markdown]
# ##### Gözlem:
# * Literacy (%) sütununa göre sıralama yapıldığında, en yüksek okur-yazarlık oranına sahip ülkeler çoğunlukla Avrupa bölgesinden (Eastern Europe, Western Europe, Baltics) geliyor.
# * İlk 5 ülkenin okur-yazarlık oranları %99,8–%99,9 aralığında, neredeyse tam okur-yazarlık seviyesinde.
# * Bu ülkeler arasında nüfus yoğunluğu ve yüzölçümü farklılıkları göze çarpıyor; örneğin, Polonya büyük bir nüfusa sahipken, Estonya ve Latvia nispeten küçük nüfuslu ülkeler.
# * Kişi başına düşen GSYİH (GDP per capita) da yüksek seviyelerde (10.200–30.900 USD), bu durum okur-yazarlık oranı ile ekonomik refah arasında bir korelasyon olabileceğini düşündürüyor.
#
# ##### Yorum:
# * Yüksek okur-yazarlık oranına sahip ülkeler, genellikle eğitim ve sosyal altyapıya güçlü yatırım yapan ülkeler olarak öne çıkıyor.
# * Bu ülkelerde ekonomik göstergeler ve yaşam kalitesi de genellikle yüksek; dolayısıyla eğitim düzeyi, ülke kalkınması ve ekonomik refah için önemli bir belirleyici olarak yorumlanabilir.
# * Analiz, okur-yazarlık oranı yüksek ülkelerin küçük veya büyük nüfuslu olabilmesine rağmen, sosyal ve ekonomik göstergelerde avantajlı olduklarını ortaya koyuyor.

# %% [markdown]
# #### En yüksek nüfus yoğunluğuna sahip ilk 10 ülke

# %%
top_10_density = data.sort_values(by='Pop. Density (per sq. mi.)', ascending=False).head(10)
top_10_density
# Out:
#          Country                               Region  Population  \
# 9       Armenia                  C.W. OF IND. STATES      2976372
# 186    Slovenia   EASTERN EUROPE                          2010347
# 202        Togo   SUB-SAHARAN AFRICA                      5548702
# 12      Austria   WESTERN EUROPE                          8192880
# 168     Romania   EASTERN EUROPE                         22303552
# 77        Ghana   SUB-SAHARAN AFRICA                     22409572
# 140  Montserrat               LATIN AMER. & CARIB            9439
# 13   Azerbaijan                  C.W. OF IND. STATES      7961619
# 56     Dominica               LATIN AMER. & CARIB           68910
# 206      Turkey   NEAR EAST                              70413958
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 9             29800                       99,9                         0,00
# 186           20273                       99,2                         0,23
# ...

# %% [markdown]
# ##### Gözlem:
# * Sıralamada okur-yazarlık oranı yüksek olan ülkeler arasında Avrupa ülkeleri (Slovenia, Austria, Romania), Orta Doğu ve Yakın Doğu ülkeleri (Turkey, Armenia, Azerbaijan) ve bazı Afrika ülkeleri (Ghana, Togo) yer alıyor.
# * Literacy (%) oranları çoğunlukla %90’ın üzerinde; en yüksek değer 99,7 (Slovenia), en düşük yüksek oran ise 86,5 (Turkey).
# * Nüfus açısından büyük farklılıklar mevcut: örneğin Turkey 70 milyonu aşan bir nüfusa sahipken, Montserrat ve Dominica gibi bazı ülkelerin nüfusu çok küçük (10 bin civarı).
# * Kişi başına düşen GSYİH’de de farklılıklar var: Austria 30.000 USD civarında yüksek gelir sağlarken, Togo ve Ghana 2.000–2.200 USD civarında düşük gelir seviyelerinde.
#
# ##### Yorum:
# * Yüksek okur-yazarlık oranı her zaman ekonomik refah ile paralel değil; örneğin, Ghana ve Togo’da okur-yazarlık yüksek olmasına rağmen GSYİH düşük.
# * Avrupa ülkeleri hem yüksek okur-yazarlık hem de yüksek kişi başı gelir ile öne çıkıyor.
# * Türkiye, okur-yazarlık oranı %86,5 ile yüksek olmakla birlikte, GSYİH ve nüfus açısından orta seviyelerde konumlanıyor.
# * Bu analiz, okur-yazarlık oranının ekonomik ve demografik göstergelerle tek başına değerlendirilemeyeceğini, bölgesel ve sosyal faktörlerin de göz önünde bulundurulması gerektiğini gösteriyor.

# %% [markdown]
# ## Genel Analiz
#
# ### 1. Nüfus:
# * En kalabalık ülkeler Çin (1,31 milyar), Hindistan (1,09 milyar) ve ABD (298 milyon) olarak öne çıkıyor.
# * Nüfus yoğunluğu açısından Bangladeş (1023 kişi/mil²) ve Gaza Strip (3968 kişi/mil²) gibi bölgeler çok yoğun, Rusya (8,4 kişi/mil²) ve Avustralya (2,6 kişi/mil²) gibi ülkelerse seyrek nüfuslu.
#
# ### 2. Ekonomi (GDP per capita):
# * Kişi başına düşen gelir en yüksek olan ülkeler arasında Avrupa ülkeleri (Austria, Slovenia, Iceland) ve ABD bulunuyor.
# * Düşük gelirli ülkeler çoğunlukla Afrika ve Asya’daki gelişmekte olan ülkeler (Togo, Ghana, East Timor).
# * Ekonomik farklılıklar, yaşam standardı ve altyapı göstergeleri ile paralellik gösteriyor.
#
# ### 3. Okur-Yazarlık Oranı (Literacy %):
# * En yüksek okur-yazarlık oranları %99 civarında ve çoğunlukla Avrupa ülkelerinde.
# * Afrika ve bazı Asya ülkelerinde okur-yazarlık daha düşük, ancak yüksek okur-yazarlık ile yüksek gelir her zaman paralel değil (ör. Ghana, Togo).
#
# ### 4. Demografi ve Sağlık:
# * Bebek ölüm oranları düşük gelirli ülkelerde yüksek (Somalia 116,7/1000), yüksek gelirli ülkelerde düşük (Iceland 3,31/1000).
# * Doğum ve ölüm oranları bölgesel farklılıklar gösteriyor; yüksek doğum oranı genellikle düşük gelirli ülkelerde.
#
# ### 5. Arazi ve Tarım:
# * Tarıma elverişli alan ve ekilebilir ürün oranı ülkeden ülkeye çok değişiyor.
# * Orta Doğu ve Afrika’da tarıma elverişli arazi düşük, Avrupa’da ve bazı Asya ülkelerinde daha yüksek.
#
# #### Genel Yorum:
# Veri seti, ülkelerin nüfus, ekonomik, sağlık, eğitim ve coğrafi göstergelerini kapsayarak kapsamlı bir karşılaştırma imkânı sağlıyor.
# Gözlemler, gelir, eğitim ve sağlık göstergeleri arasında güçlü bir bölgesel farklılık olduğunu gösteriyor.
# Nüfus yoğunluğu, ekonomik refah ve okur-yazarlık gibi göstergeler, ülkelerin kalkınma seviyesini ve altyapı ihtiyaçlarını anlamak için kullanılabilir.
